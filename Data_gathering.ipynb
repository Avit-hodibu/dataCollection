# %% [markdown]
# <a href="https://colab.research.google.com/github/Avit-hodibu/dataCollection/blob/main/Data_gathering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Work with CSV file
# comma seperated value = seperated by comma
# tsb (tab seperated value)

# %%
# import pandas
import pandas as pd

# %%
#open local csv file
df= pd.read_csv('/content/aug_train.csv')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
#open a csv file from URL
# use this code snippet directly if you are calling from website
import requests
from io import StringIO

# url of site
url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
# by using requests.get() load the content of that website and store in req
req = requests.get(url, headers=headers)
# now only select the text from req
data = StringIO(req.text)
#read the text data
df_url=pd.read_csv(data)
df_url.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %%
# when the seperator is not comma, we need to use sep ='' in parameter
# and place the symbol that seperate text of the data
# default is sep= ',' . so, we donot need to use for csv file
# but for tsv we need to use '\t that is tab
# tsv = tab seperate value
# since col does not have name so we use names= [] to set col name
df_tsv=pd.read_csv('/content/movie_titles_metadata.tsv', sep='\t', names=['sno','name','release_year','rating','votes','genres'])
df_tsv.head()
# Out:
#   sno                        name release_year  rating     votes  \
# 0  m0  10 things i hate about you         1999     6.9   62847.0
# 1  m1  1492: conquest of paradise         1992     6.2   10421.0
# 2  m2                  15 minutes         2001     6.1   25854.0
# 3  m3       2001: a space odyssey         1968     8.4  163227.0
# 4  m4                     48 hrs.         1982     6.9   22289.0
#
#                                            genres
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
# when col name is treated as row
# header of each col is show like data
# use header= parameter and set the row which need to be header
df_row=pd.read_csv('/content/test.csv', header=1) # count start from 1 not 0
df_row.head()
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %%
# changing col to index_col
# this is use by using parameter index_col =''
# put the col which you want to set as index inside comma
df_index=pd.read_csv('/content/aug_train.csv', index_col='enrollee_id')
df_index.head()
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
#
# ...

# %%
 # load only col which is need for you when loading or reading data
 # for that we need to use usecols=[] parameter and place the col name inside that you want to call
df_col = pd.read_csv('/content/aug_train.csv', usecols=['enrollee_id','gender','education_level'])
df_col.head()
# Out:
#    enrollee_id gender education_level
# 0         8949   Male        Graduate
# 1        29725   Male        Graduate
# 2        11561    NaN        Graduate
# 3        33241    NaN        Graduate
# 4          666   Male         Masters

# %%
# when need only one col
# change the pandas series use parameter squeeze=True
# but when we used to call it was changing to pandas dataframe
df_col_one=pd.read_csv('/content/aug_train.csv', usecols=['enrollee_id'], squeeze=True)
df_col_one.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2dd31aab393c> in <cell line: 4>()
#       2 # change the pandas series use parameter squeeze=True
#       3 # but when we used to call it was changing to pandas dataframe
# ----> 4 df_col_one=pd.read_csv('/content/aug_train.csv', usecols=['enrollee_id'], squeeze=True)
#       5 df_col_one.head()
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
# skiprows Parameter
# no load of data from that rows
# place the index number skiprows=[] parameter
df_skip=pd.read_csv('/content/aug_train.csv', skiprows=[0,1])
df_skip.head()
# Out:
#    29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0  11561   city_21               0.624   NaN   No relevent experience
# 1  33241  city_115               0.789   NaN   No relevent experience
# 2    666  city_162               0.767  Male  Has relevent experience
# 3  21651  city_176               0.764   NaN  Has relevent experience
# 4  28806  city_160               0.920  Male  Has relevent experience
#
#       no_enrollment     Graduate             STEM   15  50-99         Pvt Ltd  \
# 0  Full time course     Graduate             STEM    5    NaN             NaN
# 1               NaN     Graduate  Business Degree   <1    NaN         Pvt Ltd
# 2     no_enrollment      Masters             STEM  >20  50-99  Funded Startup
# 3  Part time course     Graduate             STEM   11    NaN             NaN
# 4     no_enrollment  High School              NaN    5  50-99  Funded Startup
#
#       >4  47  0.0
# 0  never  83  0.0
# 1  never  52  1.0
# ...

# %%
# load only denote number of rows
# use parameter nrows=
df_nrows=pd.read_csv('/content/aug_train.csv', nrows=4)
df_nrows.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
# 2             STEM          5          NaN          NaN        never
# 3  Business Degree         <1          NaN      Pvt Ltd        never
#
# ...

# %%
# mostly encoded in utf-8 in text and numberical
# emoji and different languages encoded in different
# error is show when it is not utf-8 ---> UnicodeDecodeError
# use parameter encoding='' and place the encode file text
# or change the encoding using text editor

# this is encode in latin-1
df_encode =pd.read_csv('/content/zomato.csv', encoding='latin-1')
df_encode.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#skip bad lines
#this will automaticlly skip the line or row which give error
#use in parser error
# error_bad_lines=False set this
df_bad =pd.read_csv('/content/BX-Books.csv', sep=';', encoding="latin-1", error_bad_lines=False)
df_bad.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-3b1b4e99ce26> in <cell line: 5>()
#       3 #use in parser error
#       4 # error_bad_lines=False set this
# ----> 5 df_bad =pd.read_csv('/content/BX-Books.csv', sep=';', encoding="latin-1") #error_bad_lines=False)
#       6 df_bad.head()
#
# ...

# %%
#dtypes parameter
# change the data type of col
df_dt = pd.read_csv('/content/aug_train.csv', dtype={'target':int})
df_dt.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
# handling date
df_date= pd.read_csv('/content/IPL Matches 2008-2020.csv', parse_dates=['date'])
# now it will treated as date not object
df_date.head()
# Out:
#        id        city       date player_of_match  \
# 0  335982   Bangalore 2008-04-18     BB McCullum
# 1  335983  Chandigarh 2008-04-19      MEK Hussey
# 2  335984       Delhi 2008-04-19     MF Maharoof
# 3  335985      Mumbai 2008-04-20      MV Boucher
# 4  335986     Kolkata 2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
# transformation or converter
# transform the data usinf converters
def rename(name):
  if name == "Royal Challengers Bangalore":
    return "RCB"
  else:
    return name

pd_convert= pd.read_csv('/content/IPL Matches 2008-2020.csv', converters={'team1': rename})
pd_convert.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                    team1                        team2  \
# 0                    RCB        Kolkata Knight Riders
# 1        Kings XI Punjab          Chennai Super Kings
# 2       Delhi Daredevils             Rajasthan Royals
# 3         Mumbai Indians  Royal Challengers Bangalore
# ...

# %%
# what type of value is consider as NaN vlaue
# we denote using parameter na_values=[]
# male is change to NaN
df_na = pd.read_csv('/content/aug_train.csv', na_values=['Male'])
df_na.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920    NaN
# 1        29725   city_40                   0.776    NaN
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
# load a huge dataset in chunks
# denote the chunk size we want to create
dfs = pd.read_csv('/content/aug_train.csv', chunksize=1000)
#loaded in small chunks one by one
for chunks in dfs:
  print(chunks.shape)
# Out:
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (1000, 14)
# (158, 14)

# %% [markdown]
# #Working with JSON/SQL
# API= JSON
# DB= SQL
# json is understand by all programming language

# %% [markdown]
# ## JSON

# %%
import pandas as pd
# to change to df
df_json=pd.read_json('/content/train.json')

# %%
df_json.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
#load from url
df_json_url=pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
df_json_url.head()
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# AED  https://www.exchangerate-api.com/terms  INR 2024-08-18
# AFN  https://www.exchangerate-api.com/terms  INR 2024-08-18
# ALL  https://www.exchangerate-api.com/terms  INR 2024-08-18
# AMD  https://www.exchangerate-api.com/terms  INR 2024-08-18
# ANG  https://www.exchangerate-api.com/terms  INR 2024-08-18
#
#      time_last_updated   rates
# AED         1723939202  0.0438
# ...

# %% [markdown]
# ##SQL

# %% [markdown]
# 1. run the database file which is in sql formate in local db by importing db in sql db
# 2. install connector. in this case we are using mysql so, !pip install mysql.connector
# 3. from a connection to db
# 4. read that and put in pandas dataframe

# %%
# !pip install mysql.connector

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='samplevideo_db')

# %%
# use sql query to call the data
df_sql=pd.read_sql_query("SELECT * FROM user_details",conn)

# %% [markdown]
# #Fetch Data from API

# %% [markdown]
# communicator medium between two software = API = Data pipelines
#
# 1. get api from site
# 2. put your api key
# 3. if you put in browser with key you will find data in json formate
# 4. if you want to look data if you do not understand copy data and paste in https://jsonviewer.stack.hu/

# %%
import pandas as pd
# for http request
import requests

# %%
# requests sending request to http which wil give us a data of that url
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1%27')
# now the send data by http after request is place in json formate
response.json()

# since i need only the 'results' and this is in dict
response_json= response.json()['results']
# changing into pandas dataframe
df_api=pd.DataFrame(response_json)

# %%
df_api.head()
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /avedvodAZUcwqevBfm8p4G2NziQ.jpg         [18, 80]  278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         [18, 80]  238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     179.721
# 1  Spanning the years 1945 to 1955, a chronicle o...     282.604
# 2  In the continuing saga of the Corleone crime f...      86.910
# ...

# %%
#since site has many pages so we need to do in loop to extract all data

df_api_all=pd.DataFrame()
page_number=5
for i in range(1,page_number):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df_api_all = df_api_all._append(temp_df,ignore_index=True)

# %%
df_api_all.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     179.721
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     282.604
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      86.910
# 3  The true story of how businessman Oskar Schind...   1993-12-15     134.879
# 4  The defense and the prosecution have rested an...   1957-04-10      66.779
#
#    vote_average  vote_count
# 0         8.705       26638
# 1         8.690       20205
# 2         8.575       12192
# 3         8.565       15595
# 4         8.543        8439

# %%
# to export
df_api_all.to_csv('movie.csv')

# %% [markdown]
# #### go in rapidaip.com and get api -> make dataset

# %% [markdown]
# # Web scraping
#
# if not given api of app then web scraping is only the option

# %%
import pandas as pd
import requests
# web scraping lib
from bs4 import BeautifulSoup

# %%
response=requests.get('https://www.ambitionbox.com/list-of-companies?page=1')

# %%
print(response)
# reponse [403] means sever has deny request.
response.content
# Out:
# <Response [403]>
# b'<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;f71ca17&#46;1723971375&#46;1abba3f5\n<P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;f71ca17&#46;1723971375&#46;1abba3f5</P>\n</BODY>\n</HTML>\n'

# %% [markdown]
# This site has use Robox.txt concept. In which file are put which you dont want to see by crawler. so, that web scraper or google search won't able to crawl.
#
# For that there is one solution that we need to show our request is send from browser.
#
# We "header" so that is send by human from browser.

# %% [markdown]
# ### this is only work for page 1
# if you want to run page more page use for loop:
# ```
# # j give the page number
# final = pd.DataFrame()
# for j in range(1,1001):
#   webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page={}'.format(j)).text
#   soup=BeautifulSoup(webpage,'lxml')
#   #other same
# # at last
# final = final._append(df, ignore_index = True)
# ```

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1', headers=headers)
# this will give whole html code of that page
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#
# ...

# %%
response_work.content

# %%
#beautifulSoup is lib use for web scraping
soup=BeautifulSoup(webpage.text,'lxml')
#This help in traverse in the html code

# %%
# arrange the content in html structure
print(soup.prettify())

# %%
# this will give all the p tag which has class name rating from the given page
soup.find_all('p', class_='rating')

# like this
soup.find_all('a', class_='review-count').text

# %%
company= soup.find_all('div', class_='company-content-wrapper')
name =[]
rating=[]
reviews=[]
ctype=[]
hq=[]
how_old=[]
no_of_employee=[]
for i in company:
  #find means single
  #.text give value in text
  #.strip will strip space
  name.append(i.find('h2').text.strip())
  rating.append(i.find('p', class_='rating').text.strip())
  reviews.append(i.find('a', class_='review-count').text.strip())
  # [0] because when p class is call with find_all it will provide 4 entity
  # because they have use same class style
  #so, when [0] it will only call 1st index value
  ctype.append(i.find_all('p', class_='infoEntity')[0].text.strip())
  # similarly [1] means 2nd index value
  hq.append(i.find_all('p', class_='infoEntity')[1].text.strip())
  how_old.append(i.find_all('p', class_='infoEntity')[2].text.strip())
  no_of_employee.append(i.find_all('p', class_='infoEntity')[3].text.strip())

# %%
# create dataframe
dict_data = {'name':name, 'rating':rating, 'reviews':reviews, 'ctype':ctype, 'hq':hq, 'how_old':how_old, 'no_of_employee':no_of_employee}
df=pd.DataFrame(dict_data)

# %%
df.head()
